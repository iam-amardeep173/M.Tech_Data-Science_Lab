# %% [markdown]
# # AMAR DEEP(M.TECH-CSE 1ST)

# %%
import numpy as np 
import pandas as pd

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#path_math = "archive/student/student-mat.csv"
path_port = "archive/student/student-por.csv"

#math = pd.read_csv(path_math, sep=";")
data = pd.read_csv(path_port, sep=";")

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# # DATA ANALYLSIS

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
len(data)
# Out:
# 649

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
data.shape
# Out:
# (649, 33)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
data.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
data.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df = data.drop_duplicates(subset ="school")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home  teacher
# 423     MS   F   16       U     GT3       T     1     3  at_home    other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        4   0  11  11
# 423  ...      4        3      3     1     3      5       11  10  11  11
#
# [2 rows x 33 columns]

# %%
data.value_counts("school")
# Out:
# school
# GP    423
# MS    226
# dtype: int64

# %%
import pandas as pd

# Example data
data = pd.DataFrame({'student-por': ['student','sex','Mjob','Fjob','famsup','Fjob','famrel','freetime','goout','Dalc','Walc','health','absences','G1','G2','G3']})
#categorical_features = {'student-por':['student','sex','Mjob','Fjob','famsup','Fjob']}
# Check if 'Color' is nominal
unique_values = data['student-por'].unique()
if len(unique_values) > 1:
    print("The 'student-por' variable is nominal.")
else:
    print("The 'student-por' variable is not be nominal.")
# Out:
# The 'student-por' variable is nominal.

# %%
import pandas as pd

# Example data
data = pd.DataFrame({'student-por': ['student','sex','Mjob','Fjob','famsup','Fjob','famrel','freetime','goout','Dalc','Walc','health','absences','G1','G2','G3']})

# Define the order of categories
student__por = ['famrel','freetime','goout','Dalc']

# Check if 'student-por' is ordinal
if all(data['student-por'].isin(student__por)):
    print("The 'student-por' variable is ordinal.")
else:
    print("The 'student-por' variable is not be ordinal.")
# Out:
# The 'student-por' variable is not be ordinal.

# %% [markdown]
# # Data Visualization

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


sns.countplot(x='school', data=df, )
plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x='age', y='G3',hue='school', data=data)
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.title('Scatter Plot of Age vs. Final Grade')
plt.xlabel('Age')
plt.ylabel('Final Grade (G3)')
plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


sns.scatterplot(x='address', y='reason',hue='school', data=data)

# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.xlabel('Address')
plt.ylabel('Reason')

plt.show()

# %%
#Multivariate Analysis
# Pair plot to visualize relationships between multiple numeric variables
sns.pairplot(data[['age', 'G1', 'G2', 'G3','Fedu']])
plt.title('Pair Plot of Numeric Variables')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.pairplot(data.drop(['Fjob'], axis = 1),hue='school', height=2)
plt.show()

# %% [markdown]
# # Histograms

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


fig, axes = plt.subplots(2, 2, figsize=(10,10))

axes[0,0].set_title("Sex")
axes[0,0].hist(df['sex'], bins=7)

axes[0,1].set_title("Age")
axes[0,1].hist(df['age'], bins=5);

axes[1,0].set_title("Address")
axes[1,0].hist(df['address'], bins=6);

axes[1,1].set_title("Internet")
axes[1,1].hist(df['internet'], bins=6);
plt.show()

# %%
# Histograms 
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

plot = sns.FacetGrid(data, hue="school")
plot.map(sns.histplot, "sex").add_legend()

plot = sns.FacetGrid(data, hue="school")
plot.map(sns.histplot, "age").add_legend()

plot = sns.FacetGrid(data, hue="school")
plot.map(sns.histplot, "address").add_legend() 
plot = sns.FacetGrid(data, hue="school")
plot.map(sns.histplot, "internet").add_legend()


plt.show()

# %%
#Univariate Analysis:

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = data.describe()

# Histogram for a numeric variable ('age')
plt.figure(figsize=(8, 6))
sns.histplot(data['age'], bins=20, kde=True)
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar plot for a categorical variable ('sex')
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', data=data)
plt.title('Count of Students by Sex')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# %%
# Handing Correlation
data.corr(method='pearson')
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.107832 -0.121050    0.034490  -0.008415  0.319968
# Medu       -0.107832  1.000000  0.647477   -0.265079   0.097006 -0.172210
# Fedu       -0.121050  0.647477  1.000000   -0.208288   0.050400 -0.165915
# traveltime  0.034490 -0.265079 -0.208288    1.000000  -0.063154  0.097730
# studytime  -0.008415  0.097006  0.050400   -0.063154   1.000000 -0.147441
# failures    0.319968 -0.172210 -0.165915    0.097730  -0.147441  1.000000
# famrel     -0.020559  0.024421  0.020256   -0.009521  -0.004127 -0.062645
# freetime   -0.004910 -0.019686  0.006841    0.000937  -0.068829  0.108995
# goout       0.112805  0.009536  0.027690    0.057454  -0.075442  0.045078
# Dalc        0.134768 -0.007018  0.000061    0.092824  -0.137585  0.105949
# Walc        0.086357 -0.019766  0.038445    0.057007  -0.214925  0.082266
# health     -0.008750  0.004614  0.044910   -0.048261  -0.056433  0.035588
# ...

# %%
# Heatmaps
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


sns.heatmap(data.corr(method='pearson').drop(['age'], axis=1).drop(['age'], axis=0),annot = True);

plt.show()

# %%
#Multivariate Analysis
# Correlation matrix to identify relationships between numeric variables
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(10, 10))

plt.subplot(221)
sns.countplot(x='Medu', hue='Fedu', data=df)

plt.subplot(222)
sns.countplot(x='Medu', hue='age', data=df)

plt.subplot(223)
sns.countplot(x='Medu', hue='G1', data=df)

plt.subplot(224)
sns.countplot(x='Medu', hue='health', data=df)

plt.show()

# %% [markdown]
# # Handling Outliers

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
#path_math = "archive/student/student-mat.csv"
#path_port = "archive/student/student-por.csv"

#math = pd.read_csv(path_math, sep=";")
#data = pd.read_csv(path_port, sep=";")


sns.boxplot(x='Medu', data=data)
# Show the plot
plt.show()

# %%
# Removing outliers
# Importing
import sklearn
from sklearn.datasets import load_boston

# Load the dataset
#path_math = "archive/student/student-mat.csv"
path_port = "archive/student/student-por.csv"

#math = pd.read_csv(path_math, sep=";")
data = pd.read_csv(path_port, sep=";")

# IQR
Q1 = np.percentile(data['age'], 25,
				interpolation = 'midpoint')

Q3 = np.percentile(data['age'], 75,
				interpolation = 'midpoint')
IQR = Q3 - Q1

print("Old Shape: ", data.shape)

# Upper bound
upper = np.where(data['age'] >= (Q3+1.5*IQR))

# Lower bound
lower = np.where(data['age'] <= (Q1-1.5*IQR))

# Removing the Outliers
data.drop(upper[0], inplace = True)
data.drop(lower[0], inplace = True)

print("New Shape: ", data.shape)

sns.boxplot(x='age', data=data)
plt.show()
# Out:
# Old Shape:  (649, 33)
# New Shape:  (646, 33)
